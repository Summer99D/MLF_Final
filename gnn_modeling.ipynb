# %% [markdown]
# # Modeling
#
# The heterogeneous graph is based on Deep Graph Library (DGL) implementation, and the training process is based on PyTorch implementation.
#
# The code is based on: https://aws.amazon.com/cn/blogs/machine-learning/detecting-fraud-in-heterogeneous-networks-using-amazon-sagemaker-and-deep-graph-library/

# %%
import os
cur_path = "/Users/yuejian/graph-fraud-detection/"
os.chdir(cur_path)
# !pwd
# Out:
# /Users/yuejian/graph-fraud-detection

# %%
# !pip install dgl==1.1.2
#-cu101
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dgl==1.1.2
#   Using cached dgl-1.1.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (558 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from dgl==1.1.2) (2.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from dgl==1.1.2) (1.13.1)
# Requirement already satisfied: networkx>=2.1 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from dgl==1.1.2) (3.2.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from dgl==1.1.2) (2.32.3)
# Requirement already satisfied: tqdm in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from dgl==1.1.2) (4.67.1)
# Requirement already satisfied: psutil>=5.8.0 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from dgl==1.1.2) (6.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->dgl==1.1.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->dgl==1.1.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->dgl==1.1.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yuejian/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->dgl==1.1.2) (2025.1.31)
# Using cached dgl-1.1.2-cp39-cp39-macosx_11_0_arm64.whl (3.8 MB)
# Installing collected packages: dgl
# Successfully installed dgl-1.1.2
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %% [markdown]
# ## Training

# %% [markdown]
# ### Prepare environment

# %%
import os
import sys
import glob

os.environ['DGLBACKEND'] = 'pytorch'

import torch as th
import dgl
import numpy as np

from gnn.estimator_fns import *
from gnn.graph_utils import *
from gnn.data import *
from gnn.utils import *
from gnn.pytorch_model import *
from train import *
# Out:
# DLG version: 1.1.2

# %% [markdown]
# ### Load data
#
# Recall the edges we defined before and the csv files we used to save them.

# %%
file_list = glob.glob('./data/*edgelist.csv')

edges = ",".join(map(lambda x: x.split("/")[-1], [file for file in file_list if "relation" in file]))
edges
# Out:
# 'relation_id_38_edgelist.csv,relation_id_09_edgelist.csv,relation_TransactionID_edgelist.csv,relation_id_08_edgelist.csv,relation_DeviceType_edgelist.csv,relation_id_02_edgelist.csv,relation_id_05_edgelist.csv,relation_card4_edgelist.csv,relation_card3_edgelist.csv,relation_id_10_edgelist.csv,relation_id_17_edgelist.csv,relation_id_21_edgelist.csv,relation_id_26_edgelist.csv,relation_P_emaildomain_edgelist.csv,relation_id_33_edgelist.csv,relation_id_34_edgelist.csv,relation_id_16_edgelist.csv,relation_id_11_edgelist.csv,relation_addr1_edgelist.csv,relation_id_04_edgelist.csv,relation_id_03_edgelist.csv,relation_card2_edgelist.csv,relation_card5_edgelist.csv,relation_id_35_edgelist.csv,relation_id_32_edgelist.csv,relation_id_27_edgelist.csv,relation_id_20_edgelist.csv,relation_id_13_edgelist.csv,relation_id_14_edgelist.csv,relation_R_emaildomain_edgelist.csv,relation_id_01_edgelist.csv,relation_id_06_edgelist.csv,relation_id_30_edgelist.csv,relation_id_37_edgelist.csv,relation_id_22_edgelist.csv,relation_id_25_edgelist.csv,relation_card1_edgelist.csv,relation_card6_edgelist.csv,relation_id_07_edgelist.csv,relation_addr2_edgelist.csv,relation_id_15_edgelist.csv,relation_id_12_edgelist.csv,relation_id_24_edgelist.csv,relation_ProductCD_edgelist.csv,relation_id_23_edgelist.csv,relation_id_36_edgelist.csv,relation_id_31_edgelist.csv,relation_id_29_edgelist.csv,relation_id_18_edgelist.csv,relation_id_28_edgelist.csv,relation_DeviceInfo_edgelist.csv,relation_id_19_edgelist.csv'

# %% [markdown]
# To train the graph neural network, we need to define a few hyperparameters that determine properties such as the class of graph neural network models we will be using, the network architecture and the optimizer and optimization parameters.
#
# Here we're setting only a few of the hyperparameters, to see all the hyperparameters and their default values, see `gnn/estimator_fns.py`. The parameters set below are:
#
# - **nodes** is the name of the file that contains the node_ids of the target nodes and the node features.
# - **edges** is a regular expression that when expanded lists all the filenames for the edgelists
# - **labels** is the name of the file tha contains the target node_ids and their labels
# - **model** specify which graph neural network to use, this should be set to r-gcn
#
# The following hyperparameters can be tuned and adjusted to improve model performance
#
# - **batch-size** is the number nodes that are used to compute a single forward pass of the GNN
# - **embedding-size** is the size of the embedding dimension for non target nodes
# - **n-neighbors** is the number of neighbours to sample for each target node during graph sampling for mini-batch training
# - **n-layers** is the number of GNN layers in the model
# - **n-epochs** is the number of training epochs for the model training job
# - **optimizer** is the optimization algorithm used for gradient based parameter updates
# - **lr** is the learning rate for parameter updates

# %% [markdown]
# ### Generate graph

# %%
print('numpy version:{} PyTorch version:{} DGL version:{}'.format(np.__version__,
                                                                    th.__version__,
                                                                    dgl.__version__))

args = parse_args()
print(args)
# Out:
# numpy version:2.0.2 PyTorch version:2.7.0 DGL version:1.1.2
# Namespace(training_dir='./data', model_dir='./model/2025_05_17_11_40_42', output_dir='./output', nodes='features.csv', target_ntype='TransactionID', edges='relation*', labels='tags.csv', new_accounts='test.csv', compute_metrics=True, threshold=0, num_gpus=0, optimizer='adam', lr=0.01, n_epochs=700, n_hidden=16, n_layers=3, weight_decay=0.0005, dropout=0.2, embedding_size=360)

# %%
args.edges = edges

args.edges = get_edgelists('relation*', args.training_dir)

g, features, target_id_to_node, id_to_node = construct_graph(args.training_dir,
                                                                args.edges,
                                                                args.nodes,
                                                                args.target_ntype)

mean, stdev, features = normalize(th.from_numpy(features))

print('feature mean shape:{}, std shape:{}'.format(mean.shape, stdev.shape))
# Out:
# Getting relation graphs from the following edge lists : ['relation_id_38_edgelist.csv', 'relation_id_09_edgelist.csv', 'relation_TransactionID_edgelist.csv', 'relation_id_08_edgelist.csv', 'relation_DeviceType_edgelist.csv', 'relation_id_02_edgelist.csv', 'relation_id_05_edgelist.csv', 'relation_card4_edgelist.csv', 'relation_card3_edgelist.csv', 'relation_id_10_edgelist.csv', 'relation_id_17_edgelist.csv', 'relation_id_21_edgelist.csv', 'relation_id_26_edgelist.csv', 'relation_P_emaildomain_edgelist.csv', 'relation_id_33_edgelist.csv', 'relation_id_34_edgelist.csv', 'relation_id_16_edgelist.csv', 'relation_id_11_edgelist.csv', 'relation_addr1_edgelist.csv', 'relation_id_04_edgelist.csv', 'relation_id_03_edgelist.csv', 'relation_card2_edgelist.csv', 'relation_card5_edgelist.csv', 'relation_id_35_edgelist.csv', 'relation_id_32_edgelist.csv', 'relation_id_27_edgelist.csv', 'relation_id_20_edgelist.csv', 'relation_id_13_edgelist.csv', 'relation_id_14_edgelist.csv', 'relation_R_emaildomain_edgelist.csv', 'relation_id_01_edgelist.csv', 'relation_id_06_edgelist.csv', 'relation_id_30_edgelist.csv', 'relation_id_37_edgelist.csv', 'relation_id_22_edgelist.csv', 'relation_id_25_edgelist.csv', 'relation_card1_edgelist.csv', 'relation_card6_edgelist.csv', 'relation_id_07_edgelist.csv', 'relation_addr2_edgelist.csv', 'relation_id_15_edgelist.csv', 'relation_id_12_edgelist.csv', 'relation_id_24_edgelist.csv', 'relation_ProductCD_edgelist.csv', 'relation_id_23_edgelist.csv', 'relation_id_36_edgelist.csv', 'relation_id_31_edgelist.csv', 'relation_id_29_edgelist.csv', 'relation_id_18_edgelist.csv', 'relation_id_28_edgelist.csv', 'relation_DeviceInfo_edgelist.csv', 'relation_id_19_edgelist.csv']
# Read edges for target<id_38> from edgelist: ./data/relation_id_38_edgelist.csv
# Read edges for target<id_09> from edgelist: ./data/relation_id_09_edgelist.csv
# Will add self loop for target later......
# Read edges for target<id_08> from edgelist: ./data/relation_id_08_edgelist.csv
# Read edges for target<DeviceType> from edgelist: ./data/relation_DeviceType_edgelist.csv
# Read edges for target<id_02> from edgelist: ./data/relation_id_02_edgelist.csv
# Read edges for target<id_05> from edgelist: ./data/relation_id_05_edgelist.csv
# Read edges for target<card4> from edgelist: ./data/relation_card4_edgelist.csv
# Read edges for target<card3> from edgelist: ./data/relation_card3_edgelist.csv
# Read edges for target<id_10> from edgelist: ./data/relation_id_10_edgelist.csv
# Read edges for target<id_17> from edgelist: ./data/relation_id_17_edgelist.csv
# Read edges for target<id_21> from edgelist: ./data/relation_id_21_edgelist.csv
# Read edges for target<id_26> from edgelist: ./data/relation_id_26_edgelist.csv
# Read edges for target<P_emaildomain> from edgelist: ./data/relation_P_emaildomain_edgelist.csv
# Read edges for target<id_33> from edgelist: ./data/relation_id_33_edgelist.csv
# Read edges for target<id_34> from edgelist: ./data/relation_id_34_edgelist.csv
# Read edges for target<id_16> from edgelist: ./data/relation_id_16_edgelist.csv
# Read edges for target<id_11> from edgelist: ./data/relation_id_11_edgelist.csv
# Read edges for target<addr1> from edgelist: ./data/relation_addr1_edgelist.csv
# Read edges for target<id_04> from edgelist: ./data/relation_id_04_edgelist.csv
# Read edges for target<id_03> from edgelist: ./data/relation_id_03_edgelist.csv
# Read edges for target<card2> from edgelist: ./data/relation_card2_edgelist.csv
# Read edges for target<card5> from edgelist: ./data/relation_card5_edgelist.csv
# Read edges for target<id_35> from edgelist: ./data/relation_id_35_edgelist.csv
# Read edges for target<id_32> from edgelist: ./data/relation_id_32_edgelist.csv
# Read edges for target<id_27> from edgelist: ./data/relation_id_27_edgelist.csv
# Read edges for target<id_20> from edgelist: ./data/relation_id_20_edgelist.csv
# Read edges for target<id_13> from edgelist: ./data/relation_id_13_edgelist.csv
# Read edges for target<id_14> from edgelist: ./data/relation_id_14_edgelist.csv
# Read edges for target<R_emaildomain> from edgelist: ./data/relation_R_emaildomain_edgelist.csv
# Read edges for target<id_01> from edgelist: ./data/relation_id_01_edgelist.csv
# Read edges for target<id_06> from edgelist: ./data/relation_id_06_edgelist.csv
# Read edges for target<id_30> from edgelist: ./data/relation_id_30_edgelist.csv
# Read edges for target<id_37> from edgelist: ./data/relation_id_37_edgelist.csv
# Read edges for target<id_22> from edgelist: ./data/relation_id_22_edgelist.csv
# Read edges for target<id_25> from edgelist: ./data/relation_id_25_edgelist.csv
# Read edges for target<card1> from edgelist: ./data/relation_card1_edgelist.csv
# Read edges for target<card6> from edgelist: ./data/relation_card6_edgelist.csv
# Read edges for target<id_07> from edgelist: ./data/relation_id_07_edgelist.csv
# Read edges for target<addr2> from edgelist: ./data/relation_addr2_edgelist.csv
# Read edges for target<id_15> from edgelist: ./data/relation_id_15_edgelist.csv
# Read edges for target<id_12> from edgelist: ./data/relation_id_12_edgelist.csv
# Read edges for target<id_24> from edgelist: ./data/relation_id_24_edgelist.csv
# Read edges for target<ProductCD> from edgelist: ./data/relation_ProductCD_edgelist.csv
# Read edges for target<id_23> from edgelist: ./data/relation_id_23_edgelist.csv
# Read edges for target<id_36> from edgelist: ./data/relation_id_36_edgelist.csv
# Read edges for target<id_31> from edgelist: ./data/relation_id_31_edgelist.csv
# Read edges for target<id_29> from edgelist: ./data/relation_id_29_edgelist.csv
# Read edges for target<id_18> from edgelist: ./data/relation_id_18_edgelist.csv
# Read edges for target<id_28> from edgelist: ./data/relation_id_28_edgelist.csv
# Read edges for target<DeviceInfo> from edgelist: ./data/relation_DeviceInfo_edgelist.csv
# Read edges for target<id_19> from edgelist: ./data/relation_id_19_edgelist.csv
# Read in features for target nodes
# Constructed heterograph with the following metagraph structure: Node types ['DeviceInfo', 'DeviceType', 'P_emaildomain', 'ProductCD', 'R_emaildomain', 'addr1', 'addr2', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6', 'id_01', 'id_02', 'id_03', 'id_04', 'id_05', 'id_06', 'id_07', 'id_08', 'id_09', 'id_10', 'id_11', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'target'], Edge types[('DeviceInfo', 'DeviceInfo<>target', 'target'), ('DeviceType', 'DeviceType<>target', 'target'), ('P_emaildomain', 'P_emaildomain<>target', 'target'), ('ProductCD', 'ProductCD<>target', 'target'), ('R_emaildomain', 'R_emaildomain<>target', 'target'), ('addr1', 'addr1<>target', 'target'), ('addr2', 'addr2<>target', 'target'), ('card1', 'card1<>target', 'target'), ('card2', 'card2<>target', 'target'), ('card3', 'card3<>target', 'target'), ('card4', 'card4<>target', 'target'), ('card5', 'card5<>target', 'target'), ('card6', 'card6<>target', 'target'), ('id_01', 'id_01<>target', 'target'), ('id_02', 'id_02<>target', 'target'), ('id_03', 'id_03<>target', 'target'), ('id_04', 'id_04<>target', 'target'), ('id_05', 'id_05<>target', 'target'), ('id_06', 'id_06<>target', 'target'), ('id_07', 'id_07<>target', 'target'), ('id_08', 'id_08<>target', 'target'), ('id_09', 'id_09<>target', 'target'), ('id_10', 'id_10<>target', 'target'), ('id_11', 'id_11<>target', 'target'), ('id_12', 'id_12<>target', 'target'), ('id_13', 'id_13<>target', 'target'), ('id_14', 'id_14<>target', 'target'), ('id_15', 'id_15<>target', 'target'), ('id_16', 'id_16<>target', 'target'), ('id_17', 'id_17<>target', 'target'), ('id_18', 'id_18<>target', 'target'), ('id_19', 'id_19<>target', 'target'), ('id_20', 'id_20<>target', 'target'), ('id_21', 'id_21<>target', 'target'), ('id_22', 'id_22<>target', 'target'), ('id_23', 'id_23<>target', 'target'), ('id_24', 'id_24<>target', 'target'), ('id_25', 'id_25<>target', 'target'), ('id_26', 'id_26<>target', 'target'), ('id_27', 'id_27<>target', 'target'), ('id_28', 'id_28<>target', 'target'), ('id_29', 'id_29<>target', 'target'), ('id_30', 'id_30<>target', 'target'), ('id_31', 'id_31<>target', 'target'), ('id_32', 'id_32<>target', 'target'), ('id_33', 'id_33<>target', 'target'), ('id_34', 'id_34<>target', 'target'), ('id_35', 'id_35<>target', 'target'), ('id_36', 'id_36<>target', 'target'), ('id_37', 'id_37<>target', 'target'), ('id_38', 'id_38<>target', 'target'), ('target', 'self_relation', 'target'), ('target', 'target<>DeviceInfo', 'DeviceInfo'), ('target', 'target<>DeviceType', 'DeviceType'), ('target', 'target<>P_emaildomain', 'P_emaildomain'), ('target', 'target<>ProductCD', 'ProductCD'), ('target', 'target<>R_emaildomain', 'R_emaildomain'), ('target', 'target<>addr1', 'addr1'), ('target', 'target<>addr2', 'addr2'), ('target', 'target<>card1', 'card1'), ('target', 'target<>card2', 'card2'), ('target', 'target<>card3', 'card3'), ('target', 'target<>card4', 'card4'), ('target', 'target<>card5', 'card5'), ('target', 'target<>card6', 'card6'), ('target', 'target<>id_01', 'id_01'), ('target', 'target<>id_02', 'id_02'), ('target', 'target<>id_03', 'id_03'), ('target', 'target<>id_04', 'id_04'), ('target', 'target<>id_05', 'id_05'), ('target', 'target<>id_06', 'id_06'), ('target', 'target<>id_07', 'id_07'), ('target', 'target<>id_08', 'id_08'), ('target', 'target<>id_09', 'id_09'), ('target', 'target<>id_10', 'id_10'), ('target', 'target<>id_11', 'id_11'), ('target', 'target<>id_12', 'id_12'), ('target', 'target<>id_13', 'id_13'), ('target', 'target<>id_14', 'id_14'), ('target', 'target<>id_15', 'id_15'), ('target', 'target<>id_16', 'id_16'), ('target', 'target<>id_17', 'id_17'), ('target', 'target<>id_18', 'id_18'), ('target', 'target<>id_19', 'id_19'), ('target', 'target<>id_20', 'id_20'), ('target', 'target<>id_21', 'id_21'), ('target', 'target<>id_2 ...
# Number of nodes of type target : 590540
# feature mean shape:torch.Size([390]), std shape:torch.Size([390])

# %%
g.nodes['target'].data['features'] = features

print("Getting labels")
n_nodes = g.number_of_nodes('target')

labels, _, test_mask = get_labels(target_id_to_node,
                                            n_nodes,
                                            args.target_ntype,
                                            os.path.join(args.training_dir, args.labels),
                                            os.path.join(args.training_dir, args.new_accounts))
print("Got labels")

labels = th.from_numpy(labels).float()
test_mask = th.from_numpy(test_mask).float()

n_nodes = th.sum(th.tensor([g.number_of_nodes(n_type) for n_type in g.ntypes]))
n_edges = th.sum(th.tensor([g.number_of_edges(e_type) for e_type in g.etypes]))

print("""----Data statistics------'
            #Nodes: {}
            #Edges: {}
            #Features Shape: {}
            #Labeled Test samples: {}""".format(n_nodes,
                                                    n_edges,
                                                    features.shape,
                                                    test_mask.sum()))
# Out:
# Getting labels
# Got labels
# ----Data statistics------'
#             #Nodes: 726345
#             #Edges: 19518802
#             #Features Shape: torch.Size([590540, 390])
#             #Labeled Test samples: 118108.0

# %% [markdown]
# ### Start training
#
# The training process and result will be saved in the same folder.

# %%
if args.num_gpus:
    cuda = True
    device = th.device('cuda:0')
else:
    cuda = False
    device = th.device('cpu')

# %%
print("Initializing Model")
in_feats = features.shape[1]
n_classes = 2

ntype_dict = {n_type: g.number_of_nodes(n_type) for n_type in g.ntypes}

model = get_model(ntype_dict, g.etypes, vars(args), in_feats, n_classes, device)
print("Initialized Model")

features = features.to(device)

labels = labels.long().to(device)
test_mask = test_mask.to(device)
# g = g.to(device)

loss = th.nn.CrossEntropyLoss()

# print(model)
optim = th.optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.weight_decay)

print("Starting Model training")

initial_record()

model, class_preds, pred_proba = train_fg(model, optim, loss, features, labels, g, g,
                                            test_mask, device, args.n_epochs,
                                            args.threshold,  args.compute_metrics)
print("Finished Model training")

print("Saving model") 

if not os.path.exists(args.model_dir):
    os.makedirs(args.model_dir)

save_model(g, model, args.model_dir, id_to_node, mean, stdev)
print("Model and metadata saved")
# Out:
# Initializing Model
# Initialized Model
# Starting Model training
# Epoch 00000, Time(s) 23.1968, Loss 0.8879, F1 0.0000
# Epoch 00001, Time(s) 22.0194, Loss 0.9047, F1 0.0000
# Epoch 00002, Time(s) 20.9196, Loss 0.6118, F1 0.0003
# Epoch 00003, Time(s) 21.0001, Loss 0.2689, F1 0.1690
# Epoch 00004, Time(s) 20.6235, Loss 0.4789, F1 0.0072
# Epoch 00005, Time(s) 20.2582, Loss 0.1690, F1 0.0000
# Epoch 00006, Time(s) 20.3039, Loss 0.1939, F1 0.0000
# Epoch 00007, Time(s) 20.3961, Loss 0.1850, F1 0.0000
# Epoch 00008, Time(s) 20.9224, Loss 0.1647, F1 0.0000
# Epoch 00009, Time(s) 20.9219, Loss 0.1495, F1 0.0017
# Epoch 00175, Time(s) 26.7676, Loss 0.0974, F1 0.4317
# Epoch 00176, Time(s) 26.7564, Loss 0.0968, F1 0.4245
# Epoch 00177, Time(s) 26.7355, Loss 0.0966, F1 0.4198
# Epoch 00178, Time(s) 26.7006, Loss 0.0965, F1 0.4396
# Epoch 00179, Time(s) 26.6632, Loss 0.0967, F1 0.3921
# Epoch 00180, Time(s) 26.6284, Loss 0.0976, F1 0.4599
# Epoch 00181, Time(s) 26.6045, Loss 0.0982, F1 0.3618
# Epoch 00182, Time(s) 26.5674, Loss 0.1002, F1 0.4488
# Epoch 00183, Time(s) 26.5344, Loss 0.0968, F1 0.4420
# Epoch 00184, Time(s) 26.5050, Loss 0.0965, F1 0.4070
# Epoch 00185, Time(s) 26.4774, Loss 0.0968, F1 0.4524
# Epoch 00186, Time(s) 26.4391, Loss 0.0975, F1 0.3946
# Epoch 00187, Time(s) 26.4334, Loss 0.0979, F1 0.4498
# Epoch 00188, Time(s) 26.4088, Loss 0.0967, F1 0.4398
# Epoch 00189, Time(s) 26.3764, Loss 0.0962, F1 0.3852
# Epoch 00190, Time(s) 26.3369, Loss 0.0977, F1 0.4662
# Epoch 00191, Time(s) 26.3048, Loss 0.0971, F1 0.4097
# Epoch 00192, Time(s) 26.2638, Loss 0.0964, F1 0.4398
# Epoch 00193, Time(s) 26.2188, Loss 0.0953, F1 0.4495
# Epoch 00194, Time(s) 26.1798, Loss 0.0951, F1 0.4152
# Epoch 00195, Time(s) 26.1641, Loss 0.0959, F1 0.4668
# Epoch 00196, Time(s) 26.1404, Loss 0.0959, F1 0.3952
# Epoch 00197, Time(s) 26.1194, Loss 0.0968, F1 0.4687
# Epoch 00198, Time(s) 26.0788, Loss 0.0963, F1 0.3897
# Epoch 00199, Time(s) 26.0359, Loss 0.0989, F1 0.4681
# Epoch 00200, Time(s) 26.0025, Loss 0.0956, F1 0.4413
# Epoch 00201, Time(s) 25.9850, Loss 0.0958, F1 0.3901
# Epoch 00202, Time(s) 25.9459, Loss 0.0975, F1 0.4803
# Epoch 00203, Time(s) 25.9117, Loss 0.0975, F1 0.3860
# Epoch 00204, Time(s) 25.8881, Loss 0.0981, F1 0.4537
# Epoch 00205, Time(s) 25.8527, Loss 0.0970, F1 0.4214
# Epoch 00206, Time(s) 25.8169, Loss 0.0970, F1 0.4531
# Epoch 00207, Time(s) 25.8075, Loss 0.0973, F1 0.4467
# Epoch 00208, Time(s) 25.7733, Loss 0.0948, F1 0.4169
# Epoch 00209, Time(s) 25.7343, Loss 0.0962, F1 0.4434
# Epoch 00210, Time(s) 25.6962, Loss 0.0940, F1 0.4693
# Epoch 00211, Time(s) 25.6712, Loss 0.0958, F1 0.4016
# Epoch 00212, Time(s) 25.6425, Loss 0.0958, F1 0.4608
# Epoch 00213, Time(s) 25.6075, Loss 0.0981, F1 0.3795
# Epoch 00214, Time(s) 25.5710, Loss 0.1026, F1 0.4461
# Epoch 00215, Time(s) 25.5376, Loss 0.1025, F1 0.4532
# Epoch 00423, Time(s) 24.7074, Loss 0.0841, F1 0.5025
# Epoch 00424, Time(s) 24.6927, Loss 0.0844, F1 0.5451
# Epoch 00425, Time(s) 24.6789, Loss 0.0830, F1 0.5195
# Epoch 00426, Time(s) 24.6625, Loss 0.0825, F1 0.5259
# Epoch 00427, Time(s) 24.6483, Loss 0.0822, F1 0.5313
# Epoch 00428, Time(s) 24.6340, Loss 0.0823, F1 0.5201
# Epoch 00429, Time(s) 24.6213, Loss 0.0832, F1 0.5245
# Epoch 00430, Time(s) 24.6051, Loss 0.0848, F1 0.5168
# Epoch 00431, Time(s) 24.5915, Loss 0.0920, F1 0.4350
# Epoch 00432, Time(s) 24.5768, Loss 0.0995, F1 0.5005
# Epoch 00433, Time(s) 24.5629, Loss 0.0890, F1 0.5362
# Epoch 00434, Time(s) 24.5488, Loss 0.0895, F1 0.4178
# Epoch 00435, Time(s) 24.5364, Loss 0.0989, F1 0.4685
# Epoch 00436, Time(s) 24.5219, Loss 0.0901, F1 0.5502
# Epoch 00437, Time(s) 24.5074, Loss 0.0930, F1 0.4916
# Epoch 00438, Time(s) 24.4961, Loss 0.0908, F1 0.4282
# Epoch 00439, Time(s) 24.4816, Loss 0.0938, F1 0.5256
# Epoch 00440, Time(s) 24.4652, Loss 0.0856, F1 0.5361
# Epoch 00441, Time(s) 24.4509, Loss 0.0931, F1 0.4316
# Epoch 00442, Time(s) 24.4366, Loss 0.0944, F1 0.4676
# Epoch 00443, Time(s) 24.4215, Loss 0.0937, F1 0.5139
# Epoch 00444, Time(s) 24.4067, Loss 0.0906, F1 0.5207
# Epoch 00445, Time(s) 24.3906, Loss 0.0870, F1 0.4629
# Epoch 00446, Time(s) 24.3751, Loss 0.0876, F1 0.4801
# Epoch 00447, Time(s) 24.3602, Loss 0.0874, F1 0.5249
# Epoch 00448, Time(s) 24.3458, Loss 0.0858, F1 0.5133
# Epoch 00449, Time(s) 24.3319, Loss 0.0857, F1 0.5075
# Epoch 00450, Time(s) 24.3167, Loss 0.0863, F1 0.4991
# Epoch 00451, Time(s) 24.3014, Loss 0.0847, F1 0.5239
# Epoch 00452, Time(s) 24.2907, Loss 0.0847, F1 0.5080
# Epoch 00453, Time(s) 24.2760, Loss 0.0842, F1 0.5113
# Epoch 00454, Time(s) 24.2620, Loss 0.0839, F1 0.5163
# Epoch 00455, Time(s) 24.2494, Loss 0.0841, F1 0.5116
# Epoch 00456, Time(s) 24.2346, Loss 0.0834, F1 0.5096
# Epoch 00457, Time(s) 24.2202, Loss 0.0832, F1 0.5328
# Epoch 00458, Time(s) 24.2068, Loss 0.0831, F1 0.5084
# Epoch 00459, Time(s) 24.1949, Loss 0.0831, F1 0.5432
# Epoch 00460, Time(s) 24.1872, Loss 0.0838, F1 0.4843
# Epoch 00461, Time(s) 24.1749, Loss 0.0880, F1 0.5378
# Epoch 00462, Time(s) 24.1661, Loss 0.0845, F1 0.5110
# Epoch 00463, Time(s) 24.1527, Loss 0.0834, F1 0.5290
# Epoch 00546, Time(s) 23.2169, Loss 0.0875, F1 0.4348
# Epoch 00547, Time(s) 23.2064, Loss 0.0903, F1 0.4752
# Epoch 00548, Time(s) 23.1972, Loss 0.0861, F1 0.5360
# Epoch 00549, Time(s) 23.1870, Loss 0.0828, F1 0.5500
# Epoch 00550, Time(s) 23.1798, Loss 0.0859, F1 0.5190
# Epoch 00551, Time(s) 23.1709, Loss 0.0822, F1 0.4923
# Epoch 00552, Time(s) 23.1612, Loss 0.0836, F1 0.5239
# Epoch 00553, Time(s) 23.1517, Loss 0.0820, F1 0.5184
# Epoch 00554, Time(s) 23.1419, Loss 0.0820, F1 0.5593
# Epoch 00555, Time(s) 23.1322, Loss 0.0831, F1 0.4700
# Epoch 00556, Time(s) 23.1223, Loss 0.0895, F1 0.5481
# Epoch 00557, Time(s) 23.1131, Loss 0.0837, F1 0.5229
# Epoch 00558, Time(s) 23.1042, Loss 0.0823, F1 0.5466
# Epoch 00559, Time(s) 23.0968, Loss 0.0814, F1 0.5305
# Epoch 00560, Time(s) 23.0907, Loss 0.0814, F1 0.5233
# Epoch 00561, Time(s) 23.0814, Loss 0.0819, F1 0.5531
# Epoch 00562, Time(s) 23.0730, Loss 0.0814, F1 0.5178
# Epoch 00563, Time(s) 23.0639, Loss 0.0811, F1 0.5407
# Epoch 00564, Time(s) 23.0573, Loss 0.0805, F1 0.5421
# Epoch 00565, Time(s) 23.0498, Loss 0.0805, F1 0.5236
# Epoch 00566, Time(s) 23.0413, Loss 0.0805, F1 0.5667
# Epoch 00567, Time(s) 23.0327, Loss 0.0813, F1 0.4886
# Epoch 00568, Time(s) 23.0250, Loss 0.0835, F1 0.5712
# Epoch 00569, Time(s) 23.0171, Loss 0.0856, F1 0.4848
# Epoch 00570, Time(s) 23.0107, Loss 0.1072, F1 0.4287
# Epoch 00571, Time(s) 23.0032, Loss 0.0988, F1 0.4995
# Epoch 00572, Time(s) 22.9966, Loss 0.0916, F1 0.5671
# Epoch 00573, Time(s) 22.9882, Loss 0.0907, F1 0.4788
# Epoch 00574, Time(s) 22.9816, Loss 0.0873, F1 0.4520
# Epoch 00575, Time(s) 22.9719, Loss 0.0911, F1 0.4982
# Epoch 00576, Time(s) 22.9640, Loss 0.0903, F1 0.4918
# Epoch 00577, Time(s) 22.9563, Loss 0.0873, F1 0.4914
# Epoch 00578, Time(s) 22.9480, Loss 0.0872, F1 0.5316
# Epoch 00579, Time(s) 22.9398, Loss 0.0863, F1 0.4780
# Epoch 00580, Time(s) 22.9322, Loss 0.0878, F1 0.5316
# Epoch 00581, Time(s) 22.9262, Loss 0.0883, F1 0.4944
# Epoch 00582, Time(s) 22.9180, Loss 0.0872, F1 0.5220
# Epoch 00583, Time(s) 22.9099, Loss 0.0851, F1 0.5430
# Epoch 00584, Time(s) 22.9037, Loss 0.0863, F1 0.4613
# Epoch 00585, Time(s) 22.8953, Loss 0.0881, F1 0.5041
# Epoch 00586, Time(s) 22.8891, Loss 0.0849, F1 0.5356
# Epoch 00587, Time(s) 22.8809, Loss 0.0866, F1 0.4937
# Epoch 00629, Time(s) 22.5584, Loss 0.1047, F1 0.4938
# Epoch 00630, Time(s) 22.5512, Loss 0.0881, F1 0.5656
# Epoch 00631, Time(s) 22.5449, Loss 0.0973, F1 0.4827
# Epoch 00632, Time(s) 22.5377, Loss 0.0891, F1 0.4997
# Epoch 00633, Time(s) 22.5304, Loss 0.0879, F1 0.5147
# Epoch 00634, Time(s) 22.5308, Loss 0.0903, F1 0.4887
# Epoch 00635, Time(s) 22.5242, Loss 0.0870, F1 0.5075
# Epoch 00636, Time(s) 22.5154, Loss 0.0874, F1 0.5286
# Epoch 00637, Time(s) 22.5094, Loss 0.0863, F1 0.5005
# Epoch 00638, Time(s) 22.5020, Loss 0.0851, F1 0.4982
# Epoch 00639, Time(s) 22.4943, Loss 0.0851, F1 0.5316
# Epoch 00640, Time(s) 22.4865, Loss 0.0851, F1 0.5092
# Epoch 00641, Time(s) 22.4793, Loss 0.0856, F1 0.5287
# Epoch 00642, Time(s) 22.4726, Loss 0.0844, F1 0.5408
# Epoch 00643, Time(s) 22.4639, Loss 0.0846, F1 0.4973
# Epoch 00644, Time(s) 22.4568, Loss 0.0839, F1 0.5286
# Epoch 00645, Time(s) 22.4500, Loss 0.0830, F1 0.5621
# Epoch 00646, Time(s) 22.4436, Loss 0.0829, F1 0.4979
# Epoch 00647, Time(s) 22.4356, Loss 0.0851, F1 0.5699
# Epoch 00648, Time(s) 22.4268, Loss 0.0841, F1 0.5298
# Epoch 00649, Time(s) 22.4185, Loss 0.0827, F1 0.5217
# Epoch 00650, Time(s) 22.4117, Loss 0.0817, F1 0.5624
# Epoch 00651, Time(s) 22.4042, Loss 0.0824, F1 0.5425
# Epoch 00652, Time(s) 22.3969, Loss 0.0816, F1 0.5583
# Epoch 00653, Time(s) 22.3894, Loss 0.0814, F1 0.4976
# Epoch 00654, Time(s) 22.3877, Loss 0.0829, F1 0.5778
# Epoch 00655, Time(s) 22.3815, Loss 0.0833, F1 0.4879
# Epoch 00656, Time(s) 22.3752, Loss 0.0863, F1 0.5446
# Epoch 00657, Time(s) 22.3690, Loss 0.0824, F1 0.5756
# Epoch 00658, Time(s) 22.3628, Loss 0.0832, F1 0.5023
# Epoch 00659, Time(s) 22.3557, Loss 0.0823, F1 0.5139
# Epoch 00660, Time(s) 22.3531, Loss 0.0826, F1 0.5635
# Epoch 00661, Time(s) 22.3459, Loss 0.0803, F1 0.5698
# Epoch 00662, Time(s) 22.3396, Loss 0.0818, F1 0.5319
# Epoch 00663, Time(s) 22.3332, Loss 0.0808, F1 0.5055
# Epoch 00664, Time(s) 22.3279, Loss 0.0815, F1 0.5687
# Epoch 00665, Time(s) 22.3205, Loss 0.0807, F1 0.5523
# Epoch 00666, Time(s) 22.3195, Loss 0.0798, F1 0.5487
# Epoch 00667, Time(s) 22.3143, Loss 0.0799, F1 0.5493
# Epoch 00668, Time(s) 22.3086, Loss 0.0789, F1 0.5553
# Epoch 00669, Time(s) 22.3012, Loss 0.0798, F1 0.5535
# Epoch 00670, Time(s) 22.2997, Loss 0.0793, F1 0.5346
# Epoch 00671, Time(s) 22.2938, Loss 0.0799, F1 0.5805
# Epoch 00672, Time(s) 22.2876, Loss 0.0793, F1 0.5344
# Epoch 00673, Time(s) 22.2807, Loss 0.0799, F1 0.5570
# Epoch 00674, Time(s) 22.2745, Loss 0.0789, F1 0.5712
# Epoch 00675, Time(s) 22.2676, Loss 0.0782, F1 0.5699
# Epoch 00676, Time(s) 22.2624, Loss 0.0779, F1 0.5547
# Epoch 00677, Time(s) 22.2562, Loss 0.0782, F1 0.5487
# Epoch 00678, Time(s) 22.2509, Loss 0.0785, F1 0.5826
# Epoch 00679, Time(s) 22.2437, Loss 0.0787, F1 0.5318
# Epoch 00680, Time(s) 22.2367, Loss 0.0808, F1 0.5699
# Epoch 00681, Time(s) 22.2306, Loss 0.0781, F1 0.5868
# Epoch 00682, Time(s) 22.2228, Loss 0.0776, F1 0.5449
# Epoch 00683, Time(s) 22.2154, Loss 0.0782, F1 0.5782
# Epoch 00684, Time(s) 22.2087, Loss 0.0771, F1 0.5733
# Epoch 00685, Time(s) 22.2015, Loss 0.0784, F1 0.5362
# Epoch 00686, Time(s) 22.1931, Loss 0.0808, F1 0.5570
# Epoch 00687, Time(s) 22.1866, Loss 0.0831, F1 0.5686
# Epoch 00688, Time(s) 22.1797, Loss 0.0809, F1 0.5150
# Epoch 00689, Time(s) 22.1743, Loss 0.0841, F1 0.5769
# Epoch 00690, Time(s) 22.1685, Loss 0.0781, F1 0.5808
# Epoch 00691, Time(s) 22.1622, Loss 0.0860, F1 0.5072
# Epoch 00692, Time(s) 22.1562, Loss 0.0992, F1 0.4243
# Epoch 00693, Time(s) 22.1495, Loss 0.1012, F1 0.5193
# Epoch 00694, Time(s) 22.1422, Loss 0.0835, F1 0.5693
# Epoch 00695, Time(s) 22.1365, Loss 0.1045, F1 0.3605
# Epoch 00696, Time(s) 22.1286, Loss 0.1144, F1 0.4616
# Epoch 00697, Time(s) 22.1231, Loss 0.0959, F1 0.4807
# Epoch 00698, Time(s) 22.1163, Loss 0.1102, F1 0.4775
# Epoch 00699, Time(s) 22.1102, Loss 0.0912, F1 0.4823
# Metrics
# Confusion Matrix:
#                                                     labels positive  labels negative
# predicted positive             1652              343
# predicted negative             2412           113701
#                                 f1: 0.5453, precision: 0.8281, recall: 0.4065, acc: 0.9767, roc: 0.9274, pr: 0.6227, ap: 0.6227
#
# Finished Model training
# Saving model
# Model and metadata saved

# %%
sorted_rels = sorted(relation_weights.items(), key=lambda x: x[1], reverse=True)
rel_names = [r for r, _ in sorted_rels]
norms = [n for _, n in sorted_rels]

top_k = 10
top_rels = sorted_rels[:top_k]
top_names = rel_names[:top_k]
top_norms = [n for _, n in top_rels]

plt.figure(figsize=(8, 5))
plt.barh(top_names[::-1], top_norms[::-1])  
plt.xlabel("Frobenius Norm")
plt.title(f"Top {top_k} Important Relations in RGCN (Layer {layer_idx})")
plt.tight_layout()
plt.show()

# %%
# %tb
# Out:
# No traceback available to show.
